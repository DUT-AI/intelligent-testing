# %%
# %pip install torch transformers pandas tqdm
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install torch torchvision torchaudio --force-reinstall
# Out:
# Note: you may need to restart the kernel to use updated packages.Collecting torch
#   Using cached torch-2.11.0-cp310-cp310-win_amd64.whl (114.5 MB)
# Collecting torchvision
#   Downloading torchvision-0.26.0-cp310-cp310-win_amd64.whl (3.7 MB)
#      ---------------------------------------- 0.0/3.7 MB ? eta -:--:--
#       --------------------------------------- 0.1/3.7 MB 1.1 MB/s eta 0:00:04
#      - -------------------------------------- 0.2/3.7 MB 1.7 MB/s eta 0:00:03
#      ----- ---------------------------------- 0.5/3.7 MB 3.3 MB/s eta 0:00:01
#      ---------- ----------------------------- 1.0/3.7 MB 5.5 MB/s eta 0:00:01
#      ---------------------- ----------------- 2.1/3.7 MB 8.8 MB/s eta 0:00:01
#      ---------------------------------------- 3.7/3.7 MB 13.0 MB/s eta 0:00:00
# Collecting torchaudio
#   Downloading torchaudio-2.11.0-cp310-cp310-win_amd64.whl (328 kB)
#      ---------------------------------------- 0.0/328.7 kB ? eta -:--:--
#      ---------------------------------------- 328.7/328.7 kB ? eta 0:00:00
# Collecting networkx>=2.5.1
#   Using cached networkx-3.4.2-py3-none-any.whl (1.7 MB)
# Collecting filelock
#   Using cached filelock-3.29.0-py3-none-any.whl (39 kB)
# Collecting setuptools<82
#   Downloading setuptools-81.0.0-py3-none-any.whl (1.1 MB)
#      ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#      ---------------------------------------- 1.1/1.1 MB 65.7 MB/s eta 0:00:00
# Collecting sympy>=1.13.3
#   Using cached sympy-1.14.0-py3-none-any.whl (6.3 MB)
# Collecting typing-extensions>=4.10.0
#   Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Collecting jinja2
#   Using cached jinja2-3.1.6-py3-none-any.whl (134 kB)
# Collecting fsspec>=0.8.5
#   Using cached fsspec-2026.4.0-py3-none-any.whl (203 kB)
# Collecting numpy
#   Using cached numpy-2.2.6-cp310-cp310-win_amd64.whl (12.9 MB)
# Collecting pillow!=8.3.*,>=5.3.0
#   Downloading pillow-12.2.0-cp310-cp310-win_amd64.whl (7.1 MB)
#      ---------------------------------------- 0.0/7.1 MB ? eta -:--:--
#      ---------------------- ----------------- 3.9/7.1 MB 83.2 MB/s eta 0:00:01
#      ---------------------------------------  7.1/7.1 MB 90.6 MB/s eta 0:00:01
#      ---------------------------------------- 7.1/7.1 MB 64.3 MB/s eta 0:00:00
# Collecting mpmath<1.4,>=1.1.0
#   Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Collecting MarkupSafe>=2.0
#   Using cached markupsafe-3.0.3-cp310-cp310-win_amd64.whl (15 kB)
# Installing collected packages: torchaudio, mpmath, typing-extensions, sympy, setuptools, pillow, numpy, networkx, MarkupSafe, fsspec, filelock, jinja2, torch, torchvision
#   Attempting uninstall: mpmath
#     Found existing installation: mpmath 1.3.0
#     Uninstalling mpmath-1.3.0:
#       Successfully uninstalled mpmath-1.3.0
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.15.0
#     Uninstalling typing_extensions-4.15.0:
#       Successfully uninstalled typing_extensions-4.15.0
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.14.0
#     Uninstalling sympy-1.14.0:
#       Successfully uninstalled sympy-1.14.0
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 65.5.0
#     Uninstalling setuptools-65.5.0:
#       Successfully uninstalled setuptools-65.5.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.2.6
#     Uninstalling numpy-2.2.6:
#       Successfully uninstalled numpy-2.2.6
#   Attempting uninstall: networkx
#     Found existing installation: networkx 3.4.2
#     Uninstalling networkx-3.4.2:
#       Successfully uninstalled networkx-3.4.2
#   Attempting uninstall: MarkupSafe
#     Found existing installation: MarkupSafe 3.0.3
#     Uninstalling MarkupSafe-3.0.3:
#       Successfully uninstalled MarkupSafe-3.0.3
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2026.4.0
#     Uninstalling fsspec-2026.4.0:
#       Successfully uninstalled fsspec-2026.4.0
#   Attempting uninstall: filelock
#     Found existing installation: filelock 3.29.0
#     Uninstalling filelock-3.29.0:
#       Successfully uninstalled filelock-3.29.0
#   Attempting uninstall: jinja2
#     Found existing installation: Jinja2 3.1.6
#     Uninstalling Jinja2-3.1.6:
#       Successfully uninstalled Jinja2-3.1.6
#   Attempting uninstall: torch
#     Found existing installation: torch 2.11.0
#     Uninstalling torch-2.11.0:
#       Successfully uninstalled torch-2.11.0
# Successfully installed MarkupSafe-3.0.3 filelock-3.29.0 fsspec-2026.4.0 jinja2-3.1.6 mpmath-1.3.0 networkx-3.4.2 numpy-2.2.6 pillow-12.2.0 setuptools-81.0.0 sympy-1.14.0 torch-2.11.0 torchaudio-2.11.0 torchvision-0.26.0 typing-extensions-4.15.0
# [notice] A new release of pip is available: 23.0.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install mkl mkl-include
# Out:
# Collecting mkl
#   Downloading mkl-2026.0.0-py2.py3-none-win_amd64.whl (180.8 MB)
#      ---------------------------------------- 0.0/180.8 MB ? eta -:--:--
#      -------------------------------------- 0.0/180.8 MB 653.6 kB/s eta 0:04:37
#      ---------------------------------------- 0.2/180.8 MB 1.5 MB/s eta 0:01:59
#      ---------------------------------------- 0.4/180.8 MB 2.7 MB/s eta 0:01:07
#      ---------------------------------------- 0.9/180.8 MB 4.9 MB/s eta 0:00:37
#      ---------------------------------------- 1.8/180.8 MB 8.3 MB/s eta 0:00:22
#       -------------------------------------- 3.3/180.8 MB 12.6 MB/s eta 0:00:15
#      - ------------------------------------- 6.1/180.8 MB 19.6 MB/s eta 0:00:09
win_amd64.whl (1.3 MB)
#      ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
#      ---------------------------------------- 1.3/1.3 MB 40.5 MB/s eta 0:00:00
# Collecting tbb==2023.*
#   Downloading tbb-2023.0.0-py3-none-win_amd64.whl (427 kB)
#      ---------------------------------------- 0.0/427.7 kB ? eta -:--:--
#      ---------------------------------------- 427.7/427.7 kB ? eta 0:00:00
# Collecting intel-openmp<2027,>=2025
#   Downloading intel_openmp-2026.0.0-py2.py3-none-win_amd64.whl (30.7 MB)
#      ---------------------------------------- 0.0/30.7 MB ? eta -:--:--
#      ---- ----------------------------------- 3.8/30.7 MB 80.2 MB/s eta 0:00:01
#      ----------- ---------------------------- 9.0/30.7 MB 95.2 MB/s eta 0:00:01
#      ----------------- -------------------- 14.2/30.7 MB 108.8 MB/s eta 0:00:01
#      ----------------------- -------------- 18.7/30.7 MB 108.8 MB/s eta 0:00:01
#      ----------------------------- --------- 23.3/30.7 MB 93.0 MB/s eta 0:00:01
#      ------------------------------------ - 29.2/30.7 MB 108.8 MB/s eta 0:00:01
#      -------------------------------------  30.7/30.7 MB 110.0 MB/s eta 0:00:01
#      -------------------------------------  30.7/30.7 MB 110.0 MB/s eta 0:00:01
#      --------------------------------------- 30.7/30.7 MB 59.8 MB/s eta 0:00:00
# Collecting onemkl-license==2026.0.0
#   Downloading onemkl_license-2026.0.0-py2.py3-none-win_amd64.whl (58 kB)
#      ---------------------------------------- 0.0/59.0 kB ? eta -:--:--
#      ---------------------------------------- 59.0/59.0 kB ? eta 0:00:00
# Collecting tcmlib==1.*
#   Downloading tcmlib-1.5.0-py2.py3-none-win_amd64.whl (366 kB)
#      ---------------------------------------- 0.0/366.7 kB ? eta -:--:--
#      ------------------------------------- 366.7/366.7 kB 22.3 MB/s eta 0:00:00
# Collecting intel-cmplr-lib-ur==2026.0.0
#   Downloading intel_cmplr_lib_ur-2026.0.0-py2.py3-none-win_amd64.whl (1.3 MB)
#      ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
#      ---------------------------------------- 1.3/1.3 MB 40.5 MB/s eta 0:00:00
# Collecting umf==1.1.*
#   Downloading umf-1.1.0-py2.py3-none-win_amd64.whl (289 kB)
#      ---------------------------------------- 0.0/289.9 kB ? eta -:--:--
#      ------------------------------------- 289.9/289.9 kB 17.5 MB/s eta 0:00:00
# Installing collected packages: tcmlib, onemkl-license, umf, tbb, mkl-include, intel-cmplr-lib-ur, intel-openmp, mkl
# Successfully installed intel-cmplr-lib-ur-2026.0.0 intel-openmp-2026.0.0 mkl-2026.0.0 mkl-include-2026.0.0 onemkl-license-2026.0.0 tbb-2023.0.0 tcmlib-1.5.0 umf-1.1.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
# Thay Admin bằng tên user của bạn
os.environ["Admin"]="TRUE"
import torch
print(torch.__version__)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[9], line 4
#       2 # Thay Admin bằng tên user của bạn
#       3 os.environ["Admin"]="TRUE"
# ----> 4 import torch
#       5 print(torch.__version__)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\__init__.py:285
#     281                     raise err
#     283         kernel32.SetErrorMode(prev_error_mode)
# --> 285     _load_dll_libraries()
#     286     del _load_dll_libraries
#     289 def _get_cuda_dep_paths(path: str, lib_folder: str, lib_name: str) -> list[str]:
#     290     # Libraries can either be in
#     291     # path/nvidia/lib_folder/lib or
#     292     # path/nvidia/cuXX/lib (since CUDA 13.0) or
#     293     # path/lib_folder/lib
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\__init__.py:268, in _load_dll_libraries()
#     264     err = ctypes.WinError(last_error)
#     265     err.strerror += (
#     266         f' Error loading "{dll}" or one of its dependencies.'
#     267     )
# --> 268     raise err
#     269 elif res is not None:
#     270     is_loaded = True
#
# OSError: [WinError 1114] A dynamic link library (DLL) initialization routine failed. Error loading "c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\lib\c10.dll" or one of its dependencies.

# %%
import json
import torch
import pandas as pd
from tqdm import tqdm
from transformers import AutoTokenizer, AutoModel

def extract_modernbert_embeddings(json_filepath, output_csv):
    # 1. Khởi tạo Tokenizer và Model ModernBERT
    # Đây là mô hình mới (2024/2025) tối ưu cho việc xử lý văn bản dài và hiệu suất cao
    model_name = "Qwen/Qwen3-Embedding-0.6B"
    print(f"--- Đang tải mô hình {model_name} ---")
    
    tokenizer = AutoTokenizer.from_pretrained(model_name)
    model = AutoModel.from_pretrained(model_name)
    
    # Kiểm tra và sử dụng GPU nếu có
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model = model.to(device)
    model.eval() # Chuyển sang chế độ inference
    print(f"Mô hình đang chạy trên: {device}")

    # 2. Đọc dữ liệu JSON
    with open(json_filepath, 'r', encoding='utf-8') as f:
        data = json.load(f)

    results = []
    
    # 3. Vòng lặp trích xuất
    print("--- Bắt đầu trích xuất Embedding 768D ---")
    for item_id, item_data in tqdm(data.items(), desc="Processing"):
        content = item_data.get("content", "")
        analysis = item_data.get("analysis", "")
        
        # Tạo chuỗi kết hợp Đề bài và Lời giải để BERT học trọn vẹn logic bài toán
        # [SEP] là token phân tách tiêu chuẩn trong BERT
        combined_text = f"Đề bài: {content} [SEP] Lời giải: {analysis}"
        
        # Tokenize văn bản, giới hạn 512 tokens (giới hạn chuẩn của BERT-base)
        inputs = tokenizer(
            combined_text, 
            return_tensors="pt", 
            truncation=True, 
            max_length=512, 
            padding=True
        ).to(device)
        
        with torch.no_grad():
            outputs = model(**inputs)
            
        # Lấy vector [CLS] - đây là vector đại diện cho toàn bộ ngữ nghĩa câu (768 chiều)
        # Chúng ta lấy ở vị trí index 0 của layer cuối cùng
        cls_embedding = outputs.last_hidden_state[:, 0, :].squeeze().cpu().numpy()
        
        # Chuẩn bị dữ liệu dòng
        row = {"ID": item_id}
        for i, val in enumerate(cls_embedding):
            row[f"BERT_{i}"] = float(val)
            
        results.append(row)

    # 4. Lưu ra file CSV
    df = pd.DataFrame(results)
    df.to_csv(output_csv, index=False)
    print(f"\n✅ Hoàn tất! Đã lưu {len(df)} vector vào file: {output_csv}")

if __name__ == "__main__":
    # Cấu hình đường dẫn file của bạn
    INPUT_JSON = "D:/IntelligentTesting/IntelligentTesting/XES3G5M/XES3G5M/metadata/question_full.json"
    OUTPUT_CSV = "bert_embeddings_768d.csv"
    
    extract_modernbert_embeddings(INPUT_JSON, OUTPUT_CSV)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[7], line 2
#       1 import json
# ----> 2 import torch
#       3 import pandas as pd
#       4 from tqdm import tqdm
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\__init__.py:285
#     281                     raise err
#     283         kernel32.SetErrorMode(prev_error_mode)
# --> 285     _load_dll_libraries()
#     286     del _load_dll_libraries
#     289 def _get_cuda_dep_paths(path: str, lib_folder: str, lib_name: str) -> list[str]:
#     290     # Libraries can either be in
#     291     # path/nvidia/lib_folder/lib or
#     292     # path/nvidia/cuXX/lib (since CUDA 13.0) or
#     293     # path/lib_folder/lib
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\__init__.py:268, in _load_dll_libraries()
#     264     err = ctypes.WinError(last_error)
#     265     err.strerror += (
#     266         f' Error loading "{dll}" or one of its dependencies.'
#     267     )
# --> 268     raise err
#     269 elif res is not None:
#     270     is_loaded = True
#
# OSError: [WinError 1114] A dynamic link library (DLL) initialization routine failed. Error loading "c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\lib\c10.dll" or one of its dependencies.
